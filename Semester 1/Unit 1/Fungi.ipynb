# %% [markdown]
# # Question:

# %% [markdown]
# ## How many mushrooms grew in a waste habitat?

# %% [markdown]
# # Study:

# %% [markdown]
# ### Im doing a census study because the question im doing "How many mushrooms grew in a waste habitat?" is a answer that can be only be answered by frequency and frequency needs me to look at the population to see which of the mushrooms are from a waste habitat? and looking at the entire population is a census study.

# %% [markdown]
# # Analysis:

# %%
import seaborn as sns

# %%
import pandas as pd

# %%
df = pd.read_csv('mushrooms.csv')

# %%
growninwaste=df[df["habitat"]=="w"]

# %%
df["habitat"].value_counts()
# Out:
# habitat
# d    3148
# g    2148
# p    1144
# l     832
# u     368
# m     292
# w     192
# Name: count, dtype: int64

# %%
print(len(growninwaste))
# Out:
# 192

# %%
ax = sns.barplot(data=df['habitat'].value_counts().reset_index(), x='habitat', y='count')

# %% [markdown]
# ## Answer:

# %% [markdown]
# ![Screenshot_2-9-2026_114134_www.desmos.com.jpeg](attachment:7ee01162-2c82-4318-8410-e040182c1fed.jpeg)

# %% [markdown]
# ### It turns out over 192 mushrooms grew in a waste habitat or rather the frequency of mushrooms that grew in a waste enviroment was 192 which means out of 8124 mushrooms only 192 mushrooms grew in a waste habitat.
