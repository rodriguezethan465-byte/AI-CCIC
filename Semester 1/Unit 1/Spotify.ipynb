# %% [markdown]
# ## My question

# %% [markdown]
# ### Do songs before 2020 get more streams then songs after 2020?

# %% [markdown]
# ## My study

# %% [markdown]
# ### My study is a obsevational study because this question requires data across two groups old songs and new songs both groups within a sample proving why my study is obsevational.

# %% [markdown]
# ## My analysis:

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df = pd.read_csv('spotify-2023.csv', encoding="latin-1")

# %%
df['streams'] = pd.to_numeric(df['streams'], errors='coerce')

# 2. Create group labels based on release year
df['era'] = df['released_year'].apply(lambda yr: 'Before 2020' if yr < 2020 else '2020 or Later')

# 3. Filter out missing stream values
plot_df = df.dropna(subset=['streams'])

# %%
plt.figure(figsize=(10, 6))

# %%
sns.histplot(
    data=plot_df,
    x='streams',
    hue='era',
    element='step',
    stat='density',
    common_norm=False,
    bins=30,
    palette={'Before 2020': 'navy', '2020 or Later': 'orange'}
)
median_old = plot_df[plot_df['era'] == 'Before 2020']['streams'].median()
median_new = plot_df[plot_df['era'] == '2020 or Later']['streams'].median()

plt.axvline(median_old, color='navy', linestyle='--', linewidth=2, label=f'Median Before 2020 ({median_old:,.0f})')
plt.axvline(median_new, color='orange', linestyle='--', linewidth=2, label=f'Median 2020+ ({median_new:,.0f})')

# %% [markdown]
# ## My conclusion:

# %% [markdown]
# ### In my histogram it compares eras before the year 2020 and after the year 2020 by seeing how many streams they have. As you can see on my histogram medians normally refer to the more average of a portion of the histogram. Which average refers to how many songs that amount of streams or more rather medians refer to the songs getting the same amount of streams in this context. As you can see the median for the era of songs 2020 or later is inbetween 0 and .5. so what does this mean? Since the amount of songs are way up there we have to simplify values on our graphs by putting in scientific notation so techinally kinda 0.4(10^9) is 400000000 or 4 million which sounds lke alot but not when you compare it to the before 2020 era streams. In the before 2020 era steams as you can see in the median the songs getting the same amount we can say its around .9 and applying that to our notation we get 9 million. Which demostrates how in the era with songs before 2020 get more streams then songs after 2020.
