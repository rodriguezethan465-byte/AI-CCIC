# %% [markdown]
# ## My Question
# ### Are people who drink take more risky bets then those who don't drink?

# %% [markdown]
# ## My Study
# ### My study is a observational study because it compares two groups in my data people who drink and people who don't and who is more likely to take risky bets when in a casino.

# %% [markdown]
# ### My Analysis

# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_theme(style="whitegrid")

# %%
df = pd.read_csv('steak.csv')

# %%
lottery_col = df.columns[1]  
   
drink_col = df.columns[3]

# %%
df_clean = df.dropna(subset=[lottery_col, drink_col])

# %%
drinkers = df_clean[df_clean[drink_col] == "Yes"]
non_drinkers = df_clean[df_clean[drink_col] == "No"]

# %%
drinkers_rel = drinkers[lottery_col].value_counts(normalize=True).round(3)
non_drinkers_rel = non_drinkers[lottery_col].value_counts(
    normalize=True
).round(3)

# %%
comparison_df = pd.DataFrame(
    {"Drinkers": drinkers_rel, "Non-Drinkers": non_drinkers_rel}
)

print("--- Relative Frequencies ---")
print(comparison_df)
# Out:
# --- Relative Frequencies ---
#                                                     Drinkers  Non-Drinkers
# Consider the following hypothetical situations:...
# Lottery A                                              0.507         0.439
# Lottery B                                              0.493         0.561

# %% [markdown]
# ## My Conclusion
#  ### I have came to one conclusion about relative frequencies with people who drink and people who don't that the relative frenquency of drinkers taking risky bets was .507 or rather 50.7% when you turn it into a percentage so it means that 50.7% of drinkers took the risker bet compared to the relative frenquency of people who don't drink which was .439 or 43.9% for those who choose the risky bet meaning thta 56.1 took the safer bet both of these datas mean that the percentage of people who drink risky gambling was higher then the percentage of people who don't drink risky gambling was lower.

# %% [markdown]
# ## Insert a screenshot of a graph you made in your investigation
# ![image.png](attachment:4aad6326-cadf-451b-bc72-bf27afe0bcfb.png)

# %% [markdown]
# ## This graph demostrates the relative frenquencys of the groups in the investigation between drinkers and non drinkers and the percents who took risky betting to nonrisky betting and further proves my point as it shows even though its a close chance with the drinking to do risky or nonrisky its a massive landslide compared to those who don't drink clearly beating those who picked risky beating as shown in the grpah above and furthrer proves my point that people who drink are more likely to do risky betting compared to those who don't drink are not as likely to do risky betting and are more likely to do nonrisky betting.
